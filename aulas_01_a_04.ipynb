# %% [markdown]
# <a href="https://colab.research.google.com/github/JaquelineJunko/alura_imersao_dados_4/blob/main/aulas_01_a_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importar Dados

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %% [markdown]
# # Aula 01
#
# Seu primeiro Colab com Python e Pandas

# %% [markdown]
# ## Exploração e Análise dos Dados

# %%
# visualizar primeiras 5 amostras
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
# visualizar 10 amostras aleatórias
dados.sample(10)
# Out:
#                     Rua                              Bairro     Cidade  \
# 5740                NaN                       Jardim Leonor  São Paulo
# 2584                NaN                   Planalto Paulista  São Paulo
# 8996                NaN                     Bosque da Saúde  São Paulo
# 4210   Rua das Camélias                        Mirandópolis  São Paulo
# 4254  Rua Felício Elias                           Aclimação  São Paulo
# 2755                NaN                       Santa Cecília  São Paulo
# 9930      Avenida Odila                   Planalto Paulista  São Paulo
# 7738                NaN                          Belenzinho  São Paulo
# 9867                NaN  Conjunto Habitacional Castro Alves  São Paulo
# 9022      Rua Abegoaria                Jardim das Bandeiras  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas         Valor
# 5740       632        4          5     10  R$ 3.700.000
# 2584       439        4          4      5  R$ 3.900.000
# ...

# %%
# obter informações do data frame
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %% [markdown]
# ### Média da metragem de todas as amostras
#
# A média de todas os imóveis no conjunto de dados é de 442,30m²

# %%
dados.Metragem.mean() # ou dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %% [markdown]
# ### Selecionar todos os imóveis do bairro "Vila Mariana"

# %%
listar_imoveis_vila_mariana = dados.Bairro == 'Vila Mariana'

# %%
imoveis_vila_mariana = dados[listar_imoveis_vila_mariana]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
media_metragem_vila_mariana = imoveis_vila_mariana.Metragem.mean()
print(f'A metragem média dos imóveis da Vila Mariana é de {media_metragem_vila_mariana:.2f} m².')
# Out:
# A metragem média dos imóveis da Vila Mariana é de 233.62 m².

# %% [markdown]
# ### Quantidade de imóveis por bairro

# %%
dados.Bairro.value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %% [markdown]
# #### Exibir o número de imóveis dos 10 primeiros bairros listados

# %%
numero_imoveis_bairro = dados['Bairro'].value_counts()

# %%
numero_imoveis_bairro[0:10].plot.bar()

# %% [markdown]
# # Aula 02
#
# Tratamento de dados e primeiros gráficos

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %% [markdown]
# O campo 'Valor' é do tipo 'object', indicando que há valores que não condizem com o tipo que deveria estar armazenado (float). Logo, é necessário realizar a análise e tratamento desses dados

# %% [markdown]
# ## Tratamento dos Dados da coluna 'Valor'

# %%
dados['Valor']
# Out:
# 0                                R$ 7.000.000
# 1                                R$ 3.700.000
# 2                                  R$ 380.000
# 3                                  R$ 685.000
# 4                                  R$ 540.000
#                          ...
# 10003                              R$ 665.000
# 10004                            R$ 2.300.000
# 10005                            R$ 1.050.000
# 10006    R$ 2.200\n                      /Mês
# 10007                              R$ 270.000
# Name: Valor, Length: 10008, dtype: object

# %%
dados['Valor'][0]
# Out:
# 'R$ 7.000.000'

# %% [markdown]
# Podemos separar o dado 'Valor' pelos seus componentes, de acordo com o método split(). No caso ideal, será retornado uma lista de duas posições, tal que lista = ['R$', 'valor_numerico'].

# %%
dados['Valor'][0].split()
# Out:
# ['R$', '7.000.000']

# %% [markdown]
# Com isso, podemos criar um novo DataFrame, em que cada coluna será representado por cada elemento da lista

# %%
dados['Valor'].str.split(expand = True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
valores_unicos = len(dados['Valor'].str.split(expand = True)[1].unique())
print(f'Há um total de {valores_unicos} preços únicos distribuídos entre os imóveis.')
# Out:
# Há um total de 1038 preços únicos distribuídos entre os imóveis.

# %%
dados['Valor'].str.split(expand = True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %% [markdown]
# Do resultados anterior, podemos concluir que alguns dos imóveis têm preços com os rótulos "Mês", "Ano" e "Dia" associado, o que indica que talvez tenham sido precificados por seus valores de aluguéis por dia, mês e ano, ao contrário dos demais, rotulados como "None".
#
# Agora, vamos incluir essas informações no nosso DataFrame original, para que possamos ter uma visão melhor.

# %% [markdown]
# ### Incluir as colunas do DataFrame auxiliar, no DataFrame original

# %%
dados[['Moeda', 'Valor_anuncio', 'Tipo_anuncio']] = dados['Valor'].str.split(expand=True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %%
# verificar imóveis em que 'Tipo_anuncio' é 'None', ou seja, os imóveis que foram precificado sem base em dia/mês/ano.
dados_filtrados = dados[dados["Tipo_anuncio"].isnull()]
dados_filtrados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# ...

# %% [markdown]
# ### Transformar 'Valor_anuncio' do tipo 'object' para 'float'
#
# O objetivo da manipulação é possibilitar a manipulação dos dados que estam em formato incorreto.
#
# Originalmente, os dados de valor eram do tipo 'object', quando na verdade representavam valores numérico, ou seja, deveriam ser 'float'. Para isso, seguimos os seguintes passos:
#
# - Dividimos os elementos de 'Valor' em uma lista, com o método split()
# - Cada elemento da lista virou uma coluna de um DataFrame, nomeados como [Moeda, Valor_anuncio, Tipo_anuncio]
# - Inserimos o novo DataFrame no DataFrame original
# - Filtramos os imóveis em que o 'Tipo_anuncio' é 'None', ou seja, o valor do imóvel não é associado ao rótulo de dia/mês/ano
# - Desses imóveis filtrados, vamos transformar seu valor no tipo float (passos a seguir)

# %%
# antes
dados_filtrados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   object
#  10  Tipo_anuncio   0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %%
# antes
dados_filtrados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %% [markdown]
# Converter a string de 'Valor_anuncio': retirando o '.' e transformando em float.
#
# É necessário retirar o '.', uma vez que foi utilizado para demarcar os milhares e não aos decimais, o que causa erro

# %%
dados_filtrados['Valor_anuncio'].str.replace('.','').astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 0        7000000.0
# 1        3700000.0
# 2         380000.0
# 3         685000.0
# 4         540000.0
#            ...
# 10002    1500000.0
# 10003     665000.0
# 10004    2300000.0
# 10005    1050000.0
# 10007     270000.0
# Name: Valor_anuncio, Length: 9156, dtype: float64

# %%
# substituir os dados convertidos no data frame original
dados_filtrados['Valor_anuncio'] = dados_filtrados['Valor_anuncio'].str.replace('.','').astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# depois
dados_filtrados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda  Valor_anuncio  \
# ...

# %%
#depois
dados_filtrados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   float64
#  10  Tipo_anuncio   0 non-null      object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 858.4+ KB

# %% [markdown]
# Nota-se que o Dtype da coluna 'Valor_anuncio' passou de 'object' para 'float64'

# %% [markdown]
# ### Algumas métricas dos dados que foram limpados

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

dados_filtrados.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio
# count   9156.00  9156.00    9156.00 9156.00        9156.00
# mean     434.42     3.45       3.80    3.96     3052202.96
# std     7856.42     1.05       1.97    2.60     3944208.19
# min       10.00     1.00       1.00    1.00       13000.00
# 25%      168.00     3.00       2.00    2.00      890000.00
# 50%      276.00     3.00       4.00    4.00     1800000.00
# 75%      450.00     4.00       5.00    5.00     3500000.00
# max   750000.00    16.00      40.00   50.00    65000000.00

# %%
dados_filtrados[["Rua", "Bairro", "Cidade"]].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(10, 8))
ax = sns.histplot(data = dados_filtrados, x = 'Valor_anuncio', kde = True)
ax.set_title('Histograma de Valor dos Imóveis')
plt.ylabel('Quantidade de Imóveis')
plt.xlabel('Valor em reais')
plt.xlim((-50, 10000000))
plt.show()

# %% [markdown]
# # Aula 03
#
# Gráficos, Time Series e Análise Exploratória

# %%
  dados_filtrados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda  Valor_anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7000000.00         None
# 1        4          4      4  R$ 3.700.000    R$     3700000.00         None
# 2        4          3      2    R$ 380.000    R$      380000.00         None
# 3        3          2      4    R$ 685.000    R$      685000.00         None
# 4        3          2      2    R$ 540.000    R$      540000.00         None

# %% [markdown]
# ## Calcular o preço do m² do imóvel com base no valor do anúncio e da metragem
#
# Aqui, calculamos o preço do m² de cada imóvel, independente de sua localização. O que pode acontecer é que imóveis discrepantes (outliers) podem nos das conclusões diferentes do padrão esperado, já que o preço depende apenas das informações de metragem e valor associadas ao imóvel.

# %%
dados_filtrados['Valor_m2'] = dados_filtrados['Valor_anuncio']/dados_filtrados['Metragem']
dados_filtrados.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda  Valor_anuncio Tipo_anuncio  \
# ...

# %% [markdown]
# ## Calcular o preço do m² dos imóveis segundo o bairro, baseado na quantidade de imóveis
#
# Nesse caso, o preço do m² do bairro é calculado considerando uma média de médias. Isso acontece porque inicialmente calculamos o valor do m² para cada imóvel, dividindo o seu valor pela sua metragem ('Valor_m2'). Em seguida, quando ocorre um agrupamento por bairros (groupby('Bairro')), **esses valores de m² são somados e divididos pela quantidade de imóveis**, ou seja, não indica necessariamente o valor do m² segundo sua metragem, mas sim uma média baseado no número de imóveis.

# %%
dados_filtrados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda  Valor_anuncio Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000    R$     7000000.00         None
# 1        4          4      4  R$ 3.700.000    R$     3700000.00         None
# 2        4          3      2    R$ 380.000    R$      380000.00         None
# 3        3          2      4    R$ 685.000    R$      685000.00         None
# 4        3          2      2    R$ 540.000    R$      540000.00         None
#
#    Valor_m2
# 0   7000.00
# 1   7459.68
# ...

# %%
dados_filtrados.groupby('Bairro').mean()
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio  \
# Bairro
# Aclimação            246.16     3.27       3.04   2.91     1763200.01
# Alto da Boa Vista    418.88     4.12       5.12   4.62     2391250.00
# Alto da Lapa         299.25     3.15       3.85   4.00     2083168.75
# Alto da Mooca        270.05     3.30       2.60   3.65     1184170.00
# Alto de Pinheiros    429.85     3.94       4.83   4.95     4782698.96
# ...                     ...      ...        ...    ...            ...
# Vila Água Funda      152.20     2.60       2.20   2.60      652000.00
# Água Branca          173.58     3.08       3.25   2.25     1226500.00
# Água Fria            165.42     2.83       3.42   2.50      927083.33
# Água Funda           139.00     3.00       2.50   2.00      545000.00
# Água Rasa            186.17     2.67       2.00   3.67      716166.67
#
#                    Valor_m2
# Bairro
# Aclimação           7656.17
# Alto da Boa Vista   5849.57
# ...

# %% [markdown]
# ## Calcular o preço do m² dos imóveis segundo o bairro em que está localizado, baseado na metragem total.
#
# Para isso, os bairros são agrupados, calculando o somatório do 'Valor_m2' dos imóveis que pertencem a cada bairro, para posterior cálculo de média.
#
# Dessa forma, podemos calcular uma média baseado no **somatório geral de metragem e valor dos imóveis**. Assim, podemos ter uma visão mais ampla do valor do m², do que aquela que depende somente da média baseado no preço de um imóvel isolado.

# %%
print('Agrupar os imóveis dos bairros em uma nova variável, calculando a soma das informações disponíveis, para posteriormente calcular a média\n')
dados_bairro = dados_filtrados.groupby('Bairro').sum()
dados_bairro
# Out:
# Agrupar os imóveis dos bairros em uma nova variável, calculando a soma das informações disponíveis, para posteriormente calcular a média
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio  \
# Bairro
# Aclimação             19447      258        240    230   139292801.00
# Alto da Boa Vista      3351       33         41     37    19130000.00
# Alto da Lapa          23940      252        308    320   166653500.00
# Alto da Mooca          5401       66         52     73    23683400.00
# Alto de Pinheiros    158616     1453       1782   1827  1764815915.00
# ...                     ...      ...        ...    ...            ...
# Vila Água Funda         761       13         11     13     3260000.00
# Água Branca            2083       37         39     27    14718000.00
# Água Fria              1985       34         41     30    11125000.00
# Água Funda              278        6          5      4     1090000.00
# ...

# %%
print('Cálculo do valor do m² dos bairros (somatório dos valores dos imóveis daquele bairro dividido pelo somatório das metragem dos imóveis naquele bairro) \n')
dados_bairro['Valor_m2_bairro'] = dados_bairro['Valor_anuncio']/dados_bairro['Metragem']
dados_bairro
# Out:
# Cálculo do valor do m² dos bairros (somatório dos valores dos imóveis daquele bairro dividido pelo somatório das metragem dos imóveis naquele bairro)
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio  \
# Bairro
# Aclimação             19447      258        240    230   139292801.00
# Alto da Boa Vista      3351       33         41     37    19130000.00
# Alto da Lapa          23940      252        308    320   166653500.00
# Alto da Mooca          5401       66         52     73    23683400.00
# Alto de Pinheiros    158616     1453       1782   1827  1764815915.00
# ...                     ...      ...        ...    ...            ...
# Vila Água Funda         761       13         11     13     3260000.00
# Água Branca            2083       37         39     27    14718000.00
# Água Fria              1985       34         41     30    11125000.00
# Água Funda              278        6          5      4     1090000.00
# ...

# %% [markdown]
# ## Vamos comparar o preço do m² obtidos nas duas abordagens
#
# Aqui, vamos considerar o exemplo do bairro da Vila Mariana. Será que a forma com que foram calculados esses valores muda o resultado obtido?

# %%
m2_n_imoveis = dados_filtrados.groupby('Bairro').mean().loc['Vila Mariana']['Valor_m2']
print(f'Valor do m² no bairro Vila Mariana, baseado na quantidade de imóveis: {m2_n_imoveis}')
# Out:
# Valor do m² no bairro Vila Mariana, baseado na quantidade de imóveis: 7913.154806155142

# %%
m2_metragem_total = dados_bairro.loc["Vila Mariana"]['Valor_m2_bairro']
print(f'Valor do m² no bairro Vila Mariana, baseado na metragem total: {m2_metragem_total}')
# Out:
# Valor do m² no bairro Vila Mariana, baseado na metragem total: 7659.510222881855

# %%
print(f'A diferença no valor do m² no bairro Vila Mariana, segundo as duas abordagens, foi de R${m2_n_imoveis-m2_metragem_total:.2f}')
# Out:
# A diferença no valor do m² no bairro Vila Mariana, segundo as duas abordagens, foi de R$253.64

# %% [markdown]
# ## Formatando o DataFrame 'dados_bairro'
#
# O DataFrame 'dados_bairro' é resultado da operação de groupby('Bairro') no conjunto de dados filtrados (que é o cojunto de dados original, mas com o valor dos imóveis formatados em float64)
#
# Essa formatação foi feita para transformar o index do DataFrame, que atualmente são os bairros, em números.

# %%
print('Índices do DataFrame são os bairros\n')
dados_bairro.head()
# Out:
# Índices do DataFrame são os bairros
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio  \
# Bairro
# Aclimação             19447      258        240    230   139292801.00
# Alto da Boa Vista      3351       33         41     37    19130000.00
# Alto da Lapa          23940      252        308    320   166653500.00
# Alto da Mooca          5401       66         52     73    23683400.00
# Alto de Pinheiros    158616     1453       1782   1827  1764815915.00
#
#                     Valor_m2  Valor_m2_bairro
# Bairro
# Aclimação          604837.39          7162.69
# Alto da Boa Vista   46796.55          5708.74
# Alto da Lapa       608538.25          6961.30
# Alto da Mooca      113834.80          4385.00
# Alto de Pinheiros 4158622.61         11126.34

# %%
dados_bairro.reset_index(inplace = True)
print('Índices do DataFrame passam a ser números\n')
dados_bairro
# Out:
# Índices do DataFrame passam a ser números
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  Valor_anuncio  \
# 0            Aclimação     19447      258        240    230   139292801.00
# 1    Alto da Boa Vista      3351       33         41     37    19130000.00
# 2         Alto da Lapa     23940      252        308    320   166653500.00
# 3        Alto da Mooca      5401       66         52     73    23683400.00
# 4    Alto de Pinheiros    158616     1453       1782   1827  1764815915.00
# ..                 ...       ...      ...        ...    ...            ...
# 692    Vila Água Funda       761       13         11     13     3260000.00
# 693        Água Branca      2083       37         39     27    14718000.00
# 694          Água Fria      1985       34         41     30    11125000.00
# 695         Água Funda       278        6          5      4     1090000.00
# 696          Água Rasa      1117       16         12     22     4297000.00
#
# ...

# %% [markdown]
# ## Análise dos 10 bairros com mais imóveis

# %%
print('Selecionar os 10 bairros com mais imóveis\n')
top10_bairros = dados_filtrados['Bairro'].value_counts()[:10].index
top10_bairros
# Out:
# Selecionar os 10 bairros com mais imóveis
# Index(['Alto de Pinheiros', 'Jardim Guedala', 'Jardim Paulista',
#        'Brooklin Paulista', 'Jardim Europa', 'Pacaembu', 'Vila Madalena',
#        'Cidade Jardim', 'Planalto Paulista', 'Jardim Leonor'],
#       dtype='object')

# %%
print('Selecionar os 10 bairros no DAtaFrame dados_bairro')
dados_bairro.query("Bairro in @top10_bairros")
# Out:
# Selecionar os 10 bairros no DAtaFrame dados_bairro
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  Valor_anuncio  \
# 4    Alto de Pinheiros    158616     1453       1782   1827  1764815915.00
# 19   Brooklin Paulista     70002      778        862    832   475796789.00
# 57       Cidade Jardim    132220      789       1008   1172  1164210900.00
# 155      Jardim Europa    118898      795        993   1056  2414172900.00
# 168     Jardim Guedala    972212     1443       2027   2161  1801165587.00
# 187      Jardim Leonor     97141      697        941    902   646326369.00
# 227    Jardim Paulista    130283     1028       1231   1171  2136081000.00
# 338           Pacaembu    100285      774        889   1028   867956500.00
# 396  Planalto Paulista     59250      636        768    713   374907000.00
# 564      Vila Madalena     66250      739        786    712   583253030.00
#
#       Valor_m2  Valor_m2_bairro
# 4   4158622.61         11126.34
# ...

# %% [markdown]
# ### Gráfico de barras considerando o valor do m² por bairro

# %%
plt.figure(figsize=(10, 8))
ax = sns.barplot(x='Bairro', y='Valor_m2_bairro', data=dados_bairro.query('Bairro in @top10_bairros'))
ax.tick_params(axis='x', rotation=45)

# %% [markdown]
# ### Gráfico boxplot considerando o valor dos imóveis do bairro

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_filtrados.query('Bairro in @top10_bairros'), x='Bairro', y='Valor_anuncio')
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
print('Plotar o mesmo gráfico acima, porém filtrando apenas imóveis com Metragem menos que 30 mil m².\n')
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_filtrados.query('Bairro in @top10_bairros & Metragem < 30000'), x='Bairro', y='Metragem')
ax.tick_params(axis='x', rotation=45)
plt.show()
# Out:
# Plotar o mesmo gráfico acima, porém filtrando apenas imóveis com Metragem menos que 30 mil m².

# %% [markdown]
# # Aula 04
#
# Missão Impossível: Cruzando bases de dados

# %% [markdown]
# ## Carregando nova base de dados IBGE
#
# Dicionário dos dados do IBGE: https://drive.google.com/file/d/1lwCaIv9Zai3L07IJtol01lgvodWkNmRK/view?usp=sharing

# %%
ibge_sp = pd.read_csv(
    'https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv',
    encoding='ISO-8859-1',
    sep=';', thousands='.', decimal=','
)
ibge_sp.dropna(how='all', axis=1, inplace=True) # remover colunas vazias
ibge_sp.head()
# Out:
#          Cod_setor  Cod_Grandes Regiï¿½es Nome_Grande_Regiao  Cod_UF  \
# 0  355030801000001                      3   Regiï¿½o Sudeste      35
# 1  355030801000002                      3   Regiï¿½o Sudeste      35
# 2  355030801000003                      3   Regiï¿½o Sudeste      35
# 3  355030801000004                      3   Regiï¿½o Sudeste      35
# 4  355030801000005                      3   Regiï¿½o Sudeste      35
#
#    Nome_da_UF   Cod_meso                  Nome_da_meso  Cod_micro  \
# 0  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 1  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 2  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 3  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 4  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
#
#   Nome_da_micro  Cod_RM  ... V003  V004    V005       V006    V007       V008  \
# ...

# %%
ibge_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18363 entries, 0 to 18362
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cod_setor              18363 non-null  int64
#  1   Cod_Grandes Regiï¿½es  18363 non-null  int64
#  2   Nome_Grande_Regiao     18363 non-null  object
#  3   Cod_UF                 18363 non-null  int64
#  4   Nome_da_UF             18363 non-null  object
#  5   Cod_meso               18363 non-null  int64
#  6   Nome_da_meso           18363 non-null  object
#  7   Cod_micro              18363 non-null  int64
#  8   Nome_da_micro          18363 non-null  object
#  9   Cod_RM                 18363 non-null  int64
#  10  Nome_da_RM             18363 non-null  object
#  11  Cod_municipio          18363 non-null  int64
#  12  Nome_do_municipio      18363 non-null  object
#  13  Cod_distrito           18363 non-null  int64
# ...

# %% [markdown]
# ## Carregando base de dados de CEP, que contém informações das latitudes e longitude das ruas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
enderecos = pd.read_csv('/content/drive/MyDrive/Imersão Dados Alura 4ª Edição/enderecos.csv')
enderecos.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   tipo_logr                      logr_nome  \
# 0       Rua               Armando Silveira
# 1       Rua       João Antônio Vasconcelos
# 2       Rua  Prefeito Agenor Barcelos Feio
# 3       Rua                Sebastião Gomes
# 4       Rua            Marquês do Alegrete
#
#                                    logr_compl numero            bairro  \
# 0                        Rua Armando Silveira    NaN            Divisa
# 1  Rua João Antônio Vasconcelos - até 627/628    627           Amizade
# 2           Rua Prefeito Agenor Barcelos Feio    NaN          Registro
# 3             Rua Sebastião Gomes - até 59/60     59          Registro
# 4                     Rua Marquês do Alegrete    NaN  Parque das Águas
#
# ...

# %% [markdown]
# ### Filtrando apenas endereços de São Paulo da base de dados CEP

# %%
print('Filtrando endereços que são apenas de São Paulo.\n')
enderecos_sp = enderecos.query('sigla_uf == "SP"')
enderecos_sp
# Out:
# Filtrando endereços que são apenas de São Paulo.
#         tipo_logr                  logr_nome  \
# 1             Rua   João Antônio Vasconcelos
# 413269        Rua                          A
# 413270        Rua                          A
# 413271        Rua                          A
# 413272        Rua               João Bandini
# ...           ...                        ...
# 1113858       Rua            Daniel Buccieri
# 1113865       Rua             Ottorino Rizzi
# 1113873       Rua  Adriano Michelutti Cândia
# 1113882   Rodovia              Mario Tonolli
# 1113884       Rua                 Tiradentes
#
#                                          logr_compl numero  \
# 1        Rua João Antônio Vasconcelos - até 627/628    627
# 413269                                        Rua A    NaN
# 413270                                        Rua A    NaN
# 413271                                        Rua A    NaN
# 413272                             Rua João Bandini    NaN
# ...

# %% [markdown]
# ### Criar nova coluna com o nome da rua formatado

# %%
# Formatar o nome da rua, juntando o seu logradouro (Rua, Rodovia, ...) com o nome do logradouro (nome da rua, rodovia...). 
# Atribuir dados em uma nova coluna
enderecos_sp['rua'] = enderecos_sp['tipo_logr'] + " " + enderecos_sp['logr_nome']

# Formatar o campo acima: todas as letras em minúsculo e sem espaços a mais entre as palavras
enderecos_sp['rua'] = enderecos_sp['rua'].str.lower().str.strip()

enderecos_sp
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         tipo_logr                  logr_nome  \
# 1             Rua   João Antônio Vasconcelos
# 413269        Rua                          A
# 413270        Rua                          A
# ...

# %% [markdown]
# ## Manipulando os dados dos imóveis de São Paulo: criando uma nova coluna com o nome da rua formatado
#
# O campo de 'Rua' da base de dados de imóveis de São Paulo (dados_filtrados) possui tanto o nome da rua quanto o número. No momento, queremos trabalhar com esse campo sem o número. Por isso, iremos remover esse informação e agregar em uma nova coluna

# %%
print('O campo "Rua" possui tanto o nome quanto o número.\n')
dados_filtrados.head()
# Out:
# O campo "Rua" possui tanto o nome quanto o número.
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda  Valor_anuncio Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000    R$     7000000.00         None
# 1        4          4      4  R$ 3.700.000    R$     3700000.00         None
# 2        4          3      2    R$ 380.000    R$      380000.00         None
# 3        3          2      4    R$ 685.000    R$      685000.00         None
# 4        3          2      2    R$ 540.000    R$      540000.00         None
#
# ...

# %%
print('Criação de uma nova coluna no DataFrame com a informação de rua sem o número.\n')

dados_filtrados['apenas_rua'] = dados_filtrados['Rua'].str.extract(r'(^[\w ]+)')
dados_filtrados['apenas_rua'] = dados_filtrados['apenas_rua'].str.lower().str.strip()

dados_filtrados.head()
# Out:
# Criação de uma nova coluna no DataFrame com a informação de rua sem o número.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# ...

# %% [markdown]
# ## Associar dados dos imóveis com suas informações de latitude e longitude
#
# Juntar dois DataFrames (DataFrame dos imóveis e DataFrame de cep)
#
# Fazer o merge de dois DataFrames. O primeiro deles (left) é contém os dados dos imóveis (metragem, valor, bairro,...) e o segundo é o DataFrame de cep das ruas de São Paulo. Porém, nesse último, apenas informação de rua, cep, latitude e longitude serão considerados.
#
# Link para função de merde: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html

# %%
# juntar dois DF. À esquerda estão dados dos imóveis e à direita estão suas latitudes e longitudes. 'how = left' indica que é um left join
dados_geo = pd.merge(left = dados_filtrados, right = enderecos_sp[['rua', 'cep', 'latitude', 'longitude']], how = "left", left_on = 'apenas_rua', right_on = 'rua').drop_duplicates(subset= dados_filtrados.columns).query('cep > 0')
dados_geo
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 5      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 6                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 7                                 NaN      Jardim Morumbi  São Paulo
# 26           Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 89956                   Avenida Odila   Planalto Paulista  São Paulo
# 89958                      Rua Tapuçu          Vila Sofia  São Paulo
# 89959                   Rua Guararema     Bosque da Saúde  São Paulo
# 89976               Rua Estero Belaco       Vila da Saúde  São Paulo
# 89977      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda  Valor_anuncio  \
# ...

# %% [markdown]
# Vincular as informações de latitude e longitude (do DataFrame dados_geo) com o codigo do setor (do DataFrame ibge_sp)

# %%
ibge_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18363 entries, 0 to 18362
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cod_setor              18363 non-null  int64
#  1   Cod_Grandes Regiï¿½es  18363 non-null  int64
#  2   Nome_Grande_Regiao     18363 non-null  object
#  3   Cod_UF                 18363 non-null  int64
#  4   Nome_da_UF             18363 non-null  object
#  5   Cod_meso               18363 non-null  int64
#  6   Nome_da_meso           18363 non-null  object
#  7   Cod_micro              18363 non-null  int64
#  8   Nome_da_micro          18363 non-null  object
#  9   Cod_RM                 18363 non-null  int64
#  10  Nome_da_RM             18363 non-null  object
#  11  Cod_municipio          18363 non-null  int64
#  12  Nome_do_municipio      18363 non-null  object
#  13  Cod_distrito           18363 non-null  int64
# ...

# %% [markdown]
# ## Problema: Como relacionar a base de imóveis com a bse de dados do IBGE
#
# Até agora:
#
# * Juntamos (merge) os DataFrames de imóveis com o DataFrame de CEP ('dado_geo'). Porém não uma ligação entre o DataFrame resultante e os dados do IBGE, uma vez que esses dados possuem apenas o 'Cod_setor' referenciando a localização.
#
# Solução: utilizar da latitude e longitude (do DataFrame dado_geo) e buscar se esse ponto no mapa pertence à localização definida pelo 'Cod_setor'. Essa localização consiste em ver se o par (longitude,latitude) está contido no polígono que define a região daquele setor.

# %%
# exemplo de ponto (longitude,latitude), que representa um imóvel.
from shapely.geometry import Point
latitude = -23.56 	
longitude = -46.59
Point(longitude, latitude)

# %%
from shapely.geometry import Polygon
Polygon([[0, 0], [1, 0], [1, 1], [0, 1], [0, 0]])

# %%
! pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 8.9 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 27.7 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 38.7 MB/s
# ...

# %%
# biblioteca para trabalhar com dados geoespaciais
import geopandas as gpd
from shapely.geometry import Point
from shapely.geometry import Polygon

# %% [markdown]
# Ler arquivo de setor censitário, que dá a informação de região ('geometry')

# %%
setor_censo = gpd.read_file(
'/content/drive/MyDrive/Imersão Dados Alura 4ª Edição/35SEE250GC_SIR.shp'
)
setor_censo.head()
# Out:
#         ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST CD_GEOCODD  \
# 0 98237.00  354100005000009  URBANO  35410000500       None  354100005
# 1 98232.00  354100005000004  URBANO  35410000500       None  354100005
# 2 98230.00  354100005000002  URBANO  35410000500       None  354100005
# 3 98229.00  354100005000001  URBANO  35410000500       None  354100005
# 4 98231.00  354100005000003  URBANO  35410000500       None  354100005
#
#      NM_DISTRIT CD_GEOCODM    NM_MUNICIP NM_MICRO                     NM_MESO  \
# 0  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 1  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 2  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 3  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 4  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
#
#      CD_GEOCODB  NM_BAIRRO  ID1  \
# 0  354100005001  Boqueirão    1
# ...

# %%
# obter o setor censitário IBGE de São Paulo
setor_censo_sp = setor_censo[setor_censo.NM_MUNICIP == "SÃO PAULO"]

# exemplo de busca de um par (longitude, latitude) nos poligonos do dataframe de regiao censitária  
setor_censo_sp[setor_censo_sp.contains(Point(-46.63, -23.58))]
# Out:
#              ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST CD_GEOCODD  \
# 60986 126568.00  355030890000080  URBANO  35503089000       None  355030890
#
#          NM_DISTRIT CD_GEOCODM NM_MUNICIP   NM_MICRO  \
# 60986  VILA MARIANA    3550308  SÃO PAULO  SÃO PAULO
#
#                           NM_MESO CD_GEOCODB NM_BAIRRO    ID1  \
# 60986  METROPOLITANA DE SÃO PAULO       None      None  60987
#
#                                                 geometry
# 60986  POLYGON ((-46.62618 -23.58169, -46.62863 -23.5...

# %% [markdown]
# Associando os imóveis com os códigos censitários do dataFrame do IBGE.

# %%
dados_geo["Point"] = ""

# criar os pontos (longitude,latitude) para cada imóvel do DataFrame
for i in dados_geo.index:
    dados_geo["Point"][i] = Point(dados_geo["longitude"][i], dados_geo["latitude"][i])

# verificar se o ponto está na regiao censitário. Caso esteja, vai retornar o código do setor censitário (CD_GEOCODI)
dados_geo['setor_censo'] = dados_geo["Point"].map(
    lambda x: setor_censo_sp.loc[setor_censo_sp.contains(x), 'CD_GEOCODI'].values
).str[0]

dados_geo
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 5      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 6                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 7                                 NaN      Jardim Morumbi  São Paulo
# 26           Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 89956                   Avenida Odila   Planalto Paulista  São Paulo
# 89958                      Rua Tapuçu          Vila Sofia  São Paulo
# ...

# %%
# dados já formatados
dados_geo = pd.read_csv("/content/drive/MyDrive/Imersão Dados Alura 4ª Edição/dados_geo.csv")
dados_geo.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3        Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                 Rua Graham Bell         Santo Amaro  São Paulo       440
#
#    Quartos  Banheiros  Vagas         Valor  Valor_anuncio  Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000     7000000.00           NaN
# 1        4          4      4  R$ 3.700.000     3700000.00           NaN
# 2        4          3      2    R$ 380.000      380000.00           NaN
# 3        3          2      2    R$ 540.000      540000.00           NaN
# 4        4          4      6  R$ 1.980.000     1980000.00           NaN
#
#    Valor_mm  Valor_m2                        rua        cep  latitude  \
# ...

# %% [markdown]
# **Recapitulando.** Para associar os imóveis com o código censitário:
#
# * Criamos um novo dataFrame, **associando as informações do imóveis com as latitudes e longitudes** (dados_geo). Para isso, **foi necessário formatar o nome da rua de ambos os dataframes** (o DataFrame dos imóveis: dados_filtrados; e do DataFrame com as coordenadas: enderecos_sp), para associação no método de merge;
# * **Importamos a base de dados** censitária (setor_censo_sp), que associa cada código de região com um polígono
# * Associamos os imóveis (dados_geo) com os códigos censitários do dataFrame do IBGE (setor_censo_sp). Adicionando as colunas com os pontos e o seu respectivo setor_senso. Para isso, verificamos se o ponto (latitude e longitude) da base dados_geo, estava contido no polígono da base (setor_censo_sp).
#
# Agora que temos o código censitário nos dados de imóveis e do IBGE, podemos cruzar essas duas bases de dados.

# %%
dados_vendas_censo = pd.merge(left = dados_geo, right = ibge_sp, how = 'left', left_on = 'setor_censo', right_on = 'Cod_setor')
dados_vendas_censo
# Out:
#                                  Rua              Bairro     Cidade  Metragem  \
# 0              Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1     Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                    Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3           Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                    Rua Graham Bell         Santo Amaro  São Paulo       440
# ...                              ...                 ...        ...       ...
# 5600                   Avenida Odila   Planalto Paulista  São Paulo       267
# 5601                      Rua Tapuçu          Vila Sofia  São Paulo        95
# 5602                   Rua Guararema     Bosque da Saúde  São Paulo       605
# 5603               Rua Estero Belaco       Vila da Saúde  São Paulo       205
# 5604      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo       122
#
# ...

# %%
dados_vendas_censo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5605 entries, 0 to 5604
# Data columns (total 51 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rua                    5605 non-null   object
#  1   Bairro                 5597 non-null   object
#  2   Cidade                 5605 non-null   object
#  3   Metragem               5605 non-null   int64
#  4   Quartos                5605 non-null   int64
#  5   Banheiros              5605 non-null   int64
#  6   Vagas                  5605 non-null   int64
#  7   Valor                  5605 non-null   object
#  8   Valor_anuncio          5605 non-null   float64
#  9   Tipo_anuncio           0 non-null      float64
#  10  Valor_mm               5605 non-null   float64
#  11  Valor_m2               5605 non-null   float64
#  12  rua                    5605 non-null   object
#  13  cep                    5605 non-null   float64
# ...

# %% [markdown]
# ## Gráfico com o valor do m² de acordo com a renda da pessoa

# %%
plt.figure(figsize=(10, 10))
plt.xlabel('Renda da pessoa responsável pelo imóvel')
plt.ylabel('Valor do m²')
sns.scatterplot(data = dados_vendas_censo, x="V005", y="Valor_m2")
